# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Utils

# %%
import keras, math
import numpy as np
import keras.backend as K
import matplotlib.pyplot as plt
from pathlib import Path

def reset_weights(model):
    session = K.get_session()
    for layer in model.layers: 
        if hasattr(layer, 'kernel_initializer'): layer.kernel.initializer.run(session=session)
        if hasattr(layer, 'bias'):
            if layer.bias and hasattr(layer, 'bias_initializer'): layer.bias.initializer.run(session=session)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #Importamos la data y la procesamos

# %%
import pandas as pd
ratings = pd.read_csv("/content/drive/My Drive/ML/myanimelist/animelists_reduced.csv")

# %%
users= pd.read_csv("/content/drive/My Drive/ML/myanimelist/users_reduced.csv")

# %%
animes= pd.read_csv("/content/drive/My Drive/ML/myanimelist/animes_reduced.csv")

# %%
# Nos quedamos solo con su username y id
users.drop(columns = ['user_watching','user_completed','user_onhold','user_dropped','user_plantowatch','user_days_spent_watching','gender','location',
                      'birth_date','access_rank','join_date','last_online','stats_mean_score','stats_rewatched','stats_episodes'], inplace = True)
users.head()
# Out:
#          username  user_id
# 0        karthiga  2255153
# 1       Damonashu    37326
# 2           bskai   228342
# 3  terune_uzumaki   327311
# 4           Bas_G  5015094

# %%
#Nos quedamos con los atributos que nos interesan de cada Data Frame
ratings.drop(columns=['my_watched_episodes', 'my_start_date', 'my_finish_date', 'my_status', 'my_rewatching', 'my_rewatching_ep', 'my_last_updated', 'my_tags'], inplace = True)
ratings.head()
# Out:
#    username  anime_id  my_score
# 0  karthiga        21         9
# 1  karthiga        59         7
# 2  karthiga        74         7
# 3  karthiga       120         7
# 4  karthiga       178         7

# %%
# Nos quedamos con los siguiente atributos en anime
# anime_id	title	type	source	episodes	score	scored_by genre
print(len(animes))
animes = animes.drop(columns = ['title_english', 'title_japanese', 'title_synonyms', 'image_url', 'status', 'airing', 'aired_string', 'aired', 'duration', 'rating', 'rank','popularity', 'members']) 
animes = animes.drop(columns = ['favorites', 'background', 'premiered', 'broadcast', 'related', 'producer', 'licensor', 'studio', 'opening_theme', 'ending_theme', 'duration_min', 'aired_from_year'])

#animes.head()
# Out:
# 5768

# %%
# Filtramos los animes que solo son de TV
anime_tv = animes[animes['type']=='TV']
anime_tv.head()
# Out:
#    anime_id                title type    source  episodes  score  scored_by  \
# 0     11013        Inu x Boku SS   TV     Manga        12   7.63     139250
# 1      2104     Seto no Hanayome   TV     Manga        26   7.89      91206
# 2      5262   Shugo Chara!! Doki   TV     Manga        51   7.55      37129
# 3       721        Princess Tutu   TV  Original        38   8.21      36501
# 4     12365  Bakuman. 3rd Season   TV     Manga        25   8.67     107767
#
#                                       genre
# 0    Comedy, Supernatural, Romance, Shounen
# 1  Comedy, Parody, Romance, School, Shounen
# 2             Comedy, Magic, School, Shoujo
# 3    Comedy, Drama, Magic, Romance, Fantasy
# 4           Comedy, Drama, Romance, Shounen

# %%
# Solo cambiamos el nombre de la columna my_score por comodidad
ratings.rename(columns= {'my_score' : 'score'}, inplace = True)
ratings.head()
# Out:
#    username  anime_id  score
# 0  karthiga        21      9
# 1  karthiga        59      7
# 2  karthiga        74      7
# 3  karthiga       120      7
# 4  karthiga       178      7

# %%
# Unimos los dos Data Frames
merged = ratings.merge(anime_tv, left_on = 'anime_id', right_on = 'anime_id', suffixes= ['_user', ''])
merged.head()
# Out:
#         username  anime_id  score_user      title type source  episodes  \
# 0       karthiga        21           9  One Piece   TV  Manga         0
# 1      Damonashu        21          10  One Piece   TV  Manga         0
# 2          bskai        21           8  One Piece   TV  Manga         0
# 3         Slimak        21          10  One Piece   TV  Manga         0
# 4  MistButterfly        21           0  One Piece   TV  Manga         0
#
#    score  scored_by                                              genre
# 0   8.54     423868  Action, Adventure, Comedy, Super Power, Drama,...
# 1   8.54     423868  Action, Adventure, Comedy, Super Power, Drama,...
# 2   8.54     423868  Action, Adventure, Comedy, Super Power, Drama,...
# 3   8.54     423868  Action, Adventure, Comedy, Super Power, Drama,...
# 4   8.54     423868  Action, Adventure, Comedy, Super Power, Drama,...

# %%
# Nos quedamos con 4*10^4 usuarios para agilizar los calculos
merged = merged[['username', 'title', 'anime_id','score_user']]
merged = merged.merge(users, left_on = 'username', right_on = 'username')
merged.head()
# Out:
#    username          title  anime_id  score_user  user_id
# 0  karthiga      One Piece        21           9  2255153
# 1  karthiga        Chobits        59           7  2255153
# 2  karthiga   Gakuen Alice        74           7  2255153
# 3  karthiga  Fruits Basket       120           7  2255153
# 4  karthiga   Ultra Maniac       178           7  2255153

# %%
# Experimentalmente con 10^4 datos no da RTE
data = merged.copy()
data.head()
# Out:
#    username          title  anime_id  score_user  user_id
# 0  karthiga      One Piece        21           9  2255153
# 1  karthiga        Chobits        59           7  2255153
# 2  karthiga   Gakuen Alice        74           7  2255153
# 3  karthiga  Fruits Basket       120           7  2255153
# 4  karthiga   Ultra Maniac       178           7  2255153

# %%
data.shape
# Out:
# (111837, 5)

# %%
data = data[data.score_user != 0] #Los 0 indican que un anime no fue calificado, por lo que procedemos a eliminarlos
data.shape
# Out:
# (69329, 5)

# %%
data.user_id = data.user_id.astype('category').cat.codes.values
data.anime_id = data.anime_id.astype('category').cat.codes.values

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size=0.2)

# %%
print("cantidad de usuarios en data: ",len(data.user_id.unique()))
print("cantidad de usuarios en train: ",len(train.user_id.unique()))
print("cantidad de usuarios en test: ",len(test.user_id.unique()))

print("cantidad de animes en data: ",len(data.anime_id.unique()))
print("cantidad de animes en train: ",len(train.anime_id.unique()))
print("cantidad de animes en test: ",len(test.anime_id.unique()))
# Out:
# cantidad de usuarios en data:  495
# cantidad de usuarios en train:  491
# cantidad de usuarios en test:  479
# cantidad de animes en data:  2462
# cantidad de animes en train:  2413
# cantidad de animes en test:  2016

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from keras import Model
from keras.layers import Input, Flatten, Embedding, Dot, Dropout, Concatenate, Dense, BatchNormalization
from IPython.display import SVG
from keras.optimizers import Adam
from keras.utils.vis_utils import model_to_dot
n_users, n_animes = len(data.user_id.unique()),len(data.anime_id.unique())
n_latent_factors = 3
print(n_animes)
# Out:
# 2462

# %% [markdown]
# #Neural Network

# %%
n_latent_factors_user = 75
n_latent_factors_anime = 75

anime_input = Input(shape=[1],name='Item')
anime_embedding = Embedding(n_animes + 1, n_latent_factors_anime, name='Anime-Embedding')(anime_input)
anime_vec = Flatten(name='FlattenAnimes')(anime_embedding)
anime_vec = Dropout(0.2)(anime_vec)

user_input = Input(shape=[1],name='User')
user_vec = Flatten(name='FlattenUsers')(Embedding(n_users + 1, n_latent_factors_user,name='User-Embedding')(user_input))
user_vec = Dropout(0.2)(user_vec)

concat = Concatenate()([anime_vec, user_vec])
concat_dropout = Dropout(0.2)(concat)
dense = Dense(200,name='FullyConnected')(concat_dropout)
#normal1= BatchNormalization()(dense)
dropout_1 = Dropout(0.2,name='Dropout1')(dense)
dense_2 = Dense(100,name='FullyConnected-1')(dropout_1)
#normal2= BatchNormalization()(dense_2)
dropout_2 = Dropout(0.2,name='Dropout2')(dense_2)
dense_3 = Dense(50,name='FullyConnected-2')(dropout_2)
#normal3= BatchNormalization()(dense_3)
dropout_3 = Dropout(0.2,name='Dropout3')(dense_3)
dense_4 = Dense(20,name='FullyConnected-3',activation='relu')(dropout_3)
#normal4= BatchNormalization()(dense_4)
#dropout_4 = Dropout(0.5,name='Dropout4')(dense_4)

result = Dense(1, activation='linear',name='Activation')(dense_4)
adam = Adam(lr=0.001)
model = Model([anime_input, user_input], result)

# %%
#DESCOMENTAR ESTA LINEA SI SE QUIERE USAR PESOS GUARDADOS ANTERIORMENTE
#model.load_weights("weights.best.hdf5")
model.compile(optimizer=adam,loss= 'mean_absolute_error')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Item (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# User (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# Anime-Embedding (Embedding)     (None, 1, 75)        184725      Item[0][0]
# __________________________________________________________________________________________________
# User-Embedding (Embedding)      (None, 1, 75)        37200       User[0][0]
# __________________________________________________________________________________________________
# FlattenAnimes (Flatten)         (None, 75)           0           Anime-Embedding[0][0]
# __________________________________________________________________________________________________
# FlattenUsers (Flatten)          (None, 75)           0           User-Embedding[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 75)           0           FlattenAnimes[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 75)           0           FlattenUsers[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 150)          0           dropout_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 150)          0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# FullyConnected (Dense)          (None, 200)          30200       dropout_9[0][0]
# __________________________________________________________________________________________________
# Dropout1 (Dropout)              (None, 200)          0           FullyConnected[0][0]
# __________________________________________________________________________________________________
# FullyConnected-1 (Dense)        (None, 100)          20100       Dropout1[0][0]
# __________________________________________________________________________________________________
# Dropout2 (Dropout)              (None, 100)          0           FullyConnected-1[0][0]
# __________________________________________________________________________________________________
# FullyConnected-2 (Dense)        (None, 50)           5050        Dropout2[0][0]
# __________________________________________________________________________________________________
# Dropout3 (Dropout)              (None, 50)           0           FullyConnected-2[0][0]
# __________________________________________________________________________________________________
# FullyConnected-3 (Dense)        (None, 20)           1020        Dropout3[0][0]
# __________________________________________________________________________________________________
# Activation (Dense)              (None, 1)            21          FullyConnected-3[0][0]
# ==================================================================================================
# Total params: 278,316
# Trainable params: 278,316
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
filepath="weights2.best.hdf5"
checkpoint= ModelCheckpoint(filepath,monitor="val_loss",verbose=1,save_best_only=True, mode="min")

# %%
reset_weights(model)
history = model.fit([train.anime_id, train.user_id], train.score_user, epochs=20,callbacks=[checkpoint], verbose=1, validation_split=0.2)
# Out:
# Train on 44370 samples, validate on 11093 samples
# Epoch 1/20
# 44370/44370 [==============================] - 15s 337us/step - loss: 1.3995 - val_loss: 1.0864
#
# Epoch 00001: val_loss improved from inf to 1.08638, saving model to weights2.best.hdf5
# Epoch 2/20
# 44370/44370 [==============================] - 14s 322us/step - loss: 1.1472 - val_loss: 1.0762
#
# Epoch 00002: val_loss improved from 1.08638 to 1.07616, saving model to weights2.best.hdf5
# Epoch 3/20
# 44370/44370 [==============================] - 15s 328us/step - loss: 1.0897 - val_loss: 1.0316
#
# Epoch 00003: val_loss improved from 1.07616 to 1.03165, saving model to weights2.best.hdf5
# Epoch 4/20
# 44370/44370 [==============================] - 15s 327us/step - loss: 1.0576 - val_loss: 1.0241
#
# Epoch 00004: val_loss improved from 1.03165 to 1.02411, saving model to weights2.best.hdf5
# Epoch 5/20
# 44370/44370 [==============================] - 15s 339us/step - loss: 1.0306 - val_loss: 1.0231
#
# Epoch 00005: val_loss improved from 1.02411 to 1.02314, saving model to weights2.best.hdf5
# Epoch 6/20
# 44370/44370 [==============================] - 15s 348us/step - loss: 1.0113 - val_loss: 1.0156
#
# Epoch 00006: val_loss improved from 1.02314 to 1.01557, saving model to weights2.best.hdf5
# Epoch 7/20
# 44370/44370 [==============================] - 15s 342us/step - loss: 1.0000 - val_loss: 1.0084
#
# Epoch 00007: val_loss improved from 1.01557 to 1.00841, saving model to weights2.best.hdf5
# Epoch 8/20
# 44370/44370 [==============================] - 15s 342us/step - loss: 0.9889 - val_loss: 1.0111
#
# Epoch 00008: val_loss did not improve from 1.00841
# Epoch 9/20
# 44370/44370 [==============================] - 15s 343us/step - loss: 0.9792 - val_loss: 1.0187
#
# Epoch 00009: val_loss did not improve from 1.00841
# Epoch 10/20
# 11488/44370 [======>.......................] - ETA: 10s - loss: 0.9495

# %%
from sklearn.metrics import mean_absolute_error

y_true = test.score_user

print(mean_absolute_error(y_true, model.predict([test.anime_id, test.user_id])))
# Out:
# 0.9894957460573737

# %%
def recommendByUser(user_id):
  dataUser= test[test.user_id==user_id]
  animesId= dataUser.anime_id.values
  animesName= dataUser.title.values
  score_predicted= model.predict([dataUser.user_id, animesId])
  scores=[]
  for i in range(len(score_predicted)):
    scores.append((animesName[i],np.round(score_predicted[i],2)[0]))
  scores=sorted(scores,key=itemgetter(1), reverse=True)

  return scores

# %%
from operator import itemgetter
userId=5
scores= recommendByUser(userId)
for i in range(len(scores)):
  print("animeId y predScore: ", scores[i])
  animes=test[test.user_id==userId]
  print("score real:",np.round(animes[animes.title==scores[i][0]].score_user.values[0],2))
  print("")
# Out:
# animeId y predScore:  ('Mushishi Zoku Shou', 9.08)
# score real: 8
#
# animeId y predScore:  ('Shigatsu wa Kimi no Uso', 8.82)
# score real: 9
#
# animeId y predScore:  ('Usagi Drop', 8.77)
# score real: 10
#
# animeId y predScore:  ('Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gakuen Koukou', 8.76)
# score real: 9
#
# animeId y predScore:  ('Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.', 8.76)
# score real: 9
#
# animeId y predScore:  ('Re:Zero kara Hajimeru Isekai Seikatsu', 8.72)
# score real: 9
#
# animeId y predScore:  ('Kuroshitsuji', 8.71)
# score real: 9
#
# animeId y predScore:  ('Ore Monogatari!!', 8.69)
# score real: 9
#
# animeId y predScore:  ('Baccano!', 8.61)
# score real: 8
#
# animeId y predScore:  ('Gosick', 8.61)
# score real: 9
#
# animeId y predScore:  ('Toradora!', 8.59)
# score real: 9
#
# animeId y predScore:  ('Kuroko no Basket 3rd Season', 8.59)
# score real: 9
#
# animeId y predScore:  ('One Punch Man', 8.58)
# score real: 9
#
# animeId y predScore:  ('D.Gray-man', 8.57)
# score real: 9
#
# animeId y predScore:  ('Kill la Kill', 8.57)
# score real: 9
#
# animeId y predScore:  ('Drifters', 8.56)
# score real: 9
#
# animeId y predScore:  ('ef: A Tale of Memories.', 8.54)
# score real: 9
#
# animeId y predScore:  ('SKET Dance', 8.51)
# score real: 9
#
# animeId y predScore:  ('Owarimonogatari', 8.41)
# score real: 8
#
# animeId y predScore:  ('Kimi ni Todoke', 8.41)
# score real: 9
#
# animeId y predScore:  ('Sword Art Online', 8.39)
# score real: 10
#
# animeId y predScore:  ('Bakuman. 2nd Season', 8.39)
# score real: 9
#
# animeId y predScore:  ('Phantom: Requiem for the Phantom', 8.38)
# score real: 9
#
# animeId y predScore:  ('Mob Psycho 100', 8.37)
# score real: 8
#
# animeId y predScore:  ('Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka', 8.37)
# score real: 9
#
# animeId y predScore:  ('Shokugeki no Souma: Ni no Sara', 8.34)
# score real: 8
#
# animeId y predScore:  ('Gin no Saji 2nd Season', 8.33)
# score real: 9
#
# animeId y predScore:  ('Beelzebub', 8.33)
# score real: 7
#
# animeId y predScore:  ('Sidonia no Kishi: Daikyuu Wakusei Seneki', 8.31)
# score real: 9
#
# animeId y predScore:  ('Golden Time', 8.29)
# score real: 8
#
# animeId y predScore:  ('Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e (TV)', 8.29)
# score real: 8
#
# animeId y predScore:  ('Sengoku Basara: Judge End', 8.29)
# score real: 6
#
# animeId y predScore:  ('Lucky☆Star', 8.28)
# score real: 9
#
# animeId y predScore:  ('Tasogare Otome x Amnesia', 8.28)
# score real: 7
#
# animeId y predScore:  ('Working!!', 8.28)
# score real: 9
#
# animeId y predScore:  ('Chuunibyou demo Koi ga Shitai! Ren', 8.27)
# score real: 8
#
# animeId y predScore:  ('Kaichou wa Maid-sama!', 8.26)
# score real: 8
#
# animeId y predScore:  ('WWW.Working!!', 8.25)
# score real: 8
#
# animeId y predScore:  ('Uchouten Kazoku 2', 8.24)
# score real: 8
#
# animeId y predScore:  ('Psycho-Pass 2', 8.22)
# score real: 9
#
# animeId y predScore:  ('Jormungand', 8.19)
# score real: 8
#
# animeId y predScore:  ('K-On!', 8.19)
# score real: 9
#
# animeId y predScore:  ('xxxHOLiC', 8.19)
# score real: 9
#
# animeId y predScore:  ('Samurai 7', 8.16)
# score real: 7
#
# animeId y predScore:  ('Area no Kishi', 8.15)
# score real: 6
#
# animeId y predScore:  ('Sengoku Basara Two', 8.13)
# score real: 6
#
# animeId y predScore:  ('Nejimaki Seirei Senki: Tenkyou no Alderamin', 8.12)
# score real: 7
#
# animeId y predScore:  ('Arakawa Under the Bridge x Bridge', 8.11)
# score real: 9
#
# animeId y predScore:  ('Pandora Hearts', 8.11)
# score real: 8
#
# animeId y predScore:  ('Shingeki no Bahamut: Genesis', 8.1)
# score real: 7
#
# animeId y predScore:  ('Aldnoah.Zero 2nd Season', 8.09)
# score real: 7
#
# animeId y predScore:  ('Yondemasu yo, Azazel-san. (TV)', 8.08)
# score real: 8
#
# animeId y predScore:  ('Hayate no Gotoku!!', 8.06)
# score real: 10
#
# animeId y predScore:  ('Senyuu. 2', 8.06)
# score real: 9
#
# animeId y predScore:  ('Natsu no Arashi!', 8.05)
# score real: 8
#
# animeId y predScore:  ('Plastic Memories', 8.05)
# score real: 9
#
# animeId y predScore:  ('Accel World', 8.05)
# score real: 9
#
# animeId y predScore:  ('Prison School', 8.04)
# score real: 9
#
# animeId y predScore:  ('Shikabane Hime: Kuro', 8.02)
# score real: 9
#
# animeId y predScore:  ('Kamisama no Inai Nichiyoubi', 7.97)
# score real: 7
#
# animeId y predScore:  ('Sora no Otoshimono: Forte', 7.95)
# score real: 9
#
# animeId y predScore:  ('Yondemasu yo, Azazel-san. Z', 7.95)
# score real: 9
#
# animeId y predScore:  ('God Eater', 7.93)
# score real: 8
#
# animeId y predScore:  ('GetBackers', 7.9)
# score real: 9
#
# animeId y predScore:  ('Shuumatsu Nani Shitemasu ka? Isogashii desu ka? Sukutte Moratte Ii desu ka?', 7.9)
# score real: 7
#
# animeId y predScore:  ('Mangaka-san to Assistant-san to The Animation', 7.88)
# score real: 7
#
# animeId y predScore:  ('Medaka Box', 7.88)
# score real: 7
#
# animeId y predScore:  ('Days (TV)', 7.87)
# score real: 8
#
# animeId y predScore:  ('Zero no Tsukaima: Futatsuki no Kishi', 7.87)
# score real: 8
#
# animeId y predScore:  ('Rakudai Kishi no Cavalry', 7.86)
# score real: 8
#
# animeId y predScore:  ('Naruto: Shippuuden', 7.86)
# score real: 8
#
# animeId y predScore:  ('Digimon Frontier', 7.83)
# score real: 6
#
# animeId y predScore:  ('Boku wa Tomodachi ga Sukunai Next', 7.81)
# score real: 7
#
# animeId y predScore:  ('Donten ni Warau', 7.8)
# score real: 8
#
# animeId y predScore:  ('Ookami-san to Shichinin no Nakama-tachi', 7.78)
# score real: 8
#
# animeId y predScore:  ('All Out!!', 7.78)
# score real: 8
#
# animeId y predScore:  ('Ore no Imouto ga Konnani Kawaii Wake ga Nai', 7.77)
# score real: 9
#
# animeId y predScore:  ('High School DxD BorN', 7.75)
# score real: 6
#
# animeId y predScore:  ('Kimi ga Aruji de Shitsuji ga Ore de', 7.74)
# score real: 7
#
# animeId y predScore:  ('Digimon Adventure 02', 7.67)
# score real: 8
#
# animeId y predScore:  ('Nourin', 7.66)
# score real: 7
#
# animeId y predScore:  ('Taimadou Gakuen 35 Shiken Shoutai', 7.63)
# score real: 7
#
# animeId y predScore:  ('Kakumeiki Valvrave 2nd Season', 7.62)
# score real: 7
#
# animeId y predScore:  ('Nyan Koi!', 7.62)
# score real: 9
#
# animeId y predScore:  ('Shinkyoku Soukai Polyphonica Crimson S', 7.59)
# score real: 9
#
# animeId y predScore:  ('Sousei no Onmyouji', 7.55)
# score real: 7
#
# animeId y predScore:  ('Needless', 7.54)
# score real: 9
#
# animeId y predScore:  ('Asu no Yoichi!', 7.49)
# score real: 8
#
# animeId y predScore:  ('Monster Musume no Iru Nichijou', 7.4)
# score real: 6
#
# animeId y predScore:  ('Dance in the Vampire Bund', 7.4)
# score real: 6
#
# animeId y predScore:  ('Rokujouma no Shinryakusha!? (TV)', 7.39)
# score real: 7
#
# animeId y predScore:  ('B-gata H-kei', 7.38)
# score real: 8
#
# animeId y predScore:  ('Nogizaka Haruka no Himitsu', 7.36)
# score real: 8
#
# animeId y predScore:  ('Tsubasa Chronicle 2nd Season', 7.32)
# score real: 9
#
# animeId y predScore:  ('ChäoS;HEAd', 7.2)
# score real: 9
#
# animeId y predScore:  ('Zetman', 7.15)
# score real: 7
#
# animeId y predScore:  ('IS: Infinite Stratos 2', 7.14)
# score real: 6
#
# animeId y predScore:  ('Shinmai Maou no Testament', 7.13)
# score real: 6
#
# animeId y predScore:  ('Freezing', 7.11)
# score real: 6
#
# animeId y predScore:  ('Kuma Miko', 7.11)
# score real: 6
#
# animeId y predScore:  ('School Days', 7.1)
# score real: 5
#
# animeId y predScore:  ('Hoshizora e Kakaru Hashi', 7.1)
# score real: 5
#
# animeId y predScore:  ('Punch Line', 7.09)
# score real: 7
#
# animeId y predScore:  ('Masamune-kun no Revenge', 7.06)
# score real: 8
#
# animeId y predScore:  ('Ookamikakushi', 6.77)
# score real: 6
#
# animeId y predScore:  ('Hitori no Shita: The Outcast', 6.67)
# score real: 7
#
# animeId y predScore:  ('Asura Cryin&#039;', 6.58)
# score real: 10
#
# animeId y predScore:  ('Hidan no Aria AA', 6.52)
# score real: 6
#
# animeId y predScore:  ('Seikon no Qwaser', 6.13)
# score real: 7
#
# animeId y predScore:  ('HenSemi (TV)', 5.96)
# score real: 6
#
# animeId y predScore:  ('Boukyaku no Senritsu', 4.87)
# score real: 6
